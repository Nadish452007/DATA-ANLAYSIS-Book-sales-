# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Books_Data_Clean.csv")
df
# Out:
#       index  Publishing Year                        Book Name  \
# 0         0           1975.0                          Beowulf
# 1         1           1987.0                 Batman: Year One
# 2         2           2015.0                Go Set a Watchman
# 3         3           2008.0  When You Are Engulfed in Flames
# 4         4           2011.0         Daughter of Smoke & Bone
# ...     ...              ...                              ...
# 1065   1065           2014.0                    Gray Mountain
# 1066   1066           1989.0                 The Power of One
# 1067   1067           1930.0               The Maltese Falcon
# 1068   1068           2011.0                       Night Road
# 1069   1069           1999.0                         Tripwire
#
#                                                  Author language_code  \
# 0                                Unknown, Seamus Heaney         en-US
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# ...

# %%
df.head()
# Out:
#    index  Publishing Year                        Book Name  \
# 0      0           1975.0                          Beowulf
# 1      1           1987.0                 Batman: Year One
# 2      2           2015.0                Go Set a Watchman
# 3      3           2008.0  When You Are Engulfed in Flames
# 4      4           2011.0         Daughter of Smoke & Bone
#
#                                               Author language_code  \
# 0                             Unknown, Seamus Heaney         en-US
# 1  Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# 2                                         Harper Lee           eng
# 3                                      David Sedaris         en-US
# 4                                       Laini Taylor           eng
#
#   Author_Rating  Book_average_rating  Book_ratings_count          genre  \
# 0        Novice                 3.42              155903  genre fiction
# ...

# %%
df.describe()
# Out:
#              index  Publishing Year  Book_average_rating  Book_ratings_count  \
# count  1070.000000      1069.000000          1070.000000         1070.000000
# mean    534.500000      1971.377923             4.007000        94909.913084
# std     309.026698       185.080257             0.247244        31513.242518
# min       0.000000      -560.000000             2.970000        27308.000000
# 25%     267.250000      1985.000000             3.850000        70398.000000
# 50%     534.500000      2003.000000             4.015000        89309.000000
# 75%     801.750000      2010.000000             4.170000       113906.500000
# max    1069.000000      2016.000000             4.770000       206792.000000
#
#         gross sales  publisher revenue   sale price   sales rank    units sold
# count   1070.000000        1070.000000  1070.000000  1070.000000   1070.000000
# mean    1856.622944         843.281030     4.869561   611.652336   9676.980374
# ...

# %%
df=df[df["Publishing Year"]>1900]
df
# Out:
#       index  Publishing Year                        Book Name  \
# 0         0           1975.0                          Beowulf
# 1         1           1987.0                 Batman: Year One
# 2         2           2015.0                Go Set a Watchman
# 3         3           2008.0  When You Are Engulfed in Flames
# 4         4           2011.0         Daughter of Smoke & Bone
# ...     ...              ...                              ...
# 1065   1065           2014.0                    Gray Mountain
# 1066   1066           1989.0                 The Power of One
# 1067   1067           1930.0               The Maltese Falcon
# 1068   1068           2011.0                       Night Road
# 1069   1069           1999.0                         Tripwire
#
#                                                  Author language_code  \
# 0                                Unknown, Seamus Heaney         en-US
# 1     Frank Miller, David Mazzucchelli, Richmond Lew...           eng
# ...

# %%
df.isna().sum()
# Out:
# index                   0
# Publishing Year         0
# Book Name              21
# Author                  0
# language_code          49
# Author_Rating           0
# Book_average_rating     0
# Book_ratings_count      0
# genre                   0
# gross sales             0
# publisher revenue       0
# sale price              0
# sales rank              0
# Publisher               0
# units sold              0
# dtype: int64

# %%
df.dropna(subset="Book Name",inplace=True)
# Out:
# C:\Users\Nadish\AppData\Local\Temp\ipykernel_20464\114106859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset="Book Name",inplace=True)

# %%
df.nunique()
# Out:
# index                  988
# Publishing Year        101
# Book Name              987
# Author                 669
# language_code            8
# Author_Rating            4
# Book_average_rating    133
# Book_ratings_count     983
# genre                    4
# gross sales            774
# publisher revenue      570
# sale price             143
# sales rank             818
# Publisher                9
# units sold             470
# dtype: int64

# %%
plt.hist(df["Publishing Year"])
plt.xlabel("YEAR")
plt.ylabel("frequencys")
plt.title("Graph for publishing year",color="red")
plt.show()

# %%
colors=["Orange","blue","green"]
h=df["genre"].value_counts()
h.plot(kind="bar",color=colors)
plt.xlabel("genre")
plt.ylabel("number of books")
plt.title("number of books in each genre")
plt.show()

# %%
df.groupby(["Author","gross sales","Book_average_rating"])["sale price"].sum().sort_values(ascending=True).head()
# Out:
# Author                          gross sales  Book_average_rating
# Walter M. Miller Jr.            106.92       3.97                   0.99
# Vanessa Diffenbaugh             1964.16      4.07                   0.99
# T̩a Obreht                     113.85       3.37                   0.99
# Truman Capote                   792.00       3.89                   0.99
# Adam Mansbach, Ricardo Cort̩s  113.85       4.26                   0.99
# Name: sale price, dtype: float64

# %%
sns.boxplot(x="genre",y="Book_ratings_count",data=df, color="#1E93AB")
plt.xlabel("genre")
plt.ylabel("counts for the books")
plt.title("number of books in each rating_count")
plt.show()

# %%
plt.scatter(df["sale price"],df["units sold"])
plt.ylabel("UNIT SALE")
plt.xlabel("SALE PRICE")
plt.show()

# %%
h=df["language_code"].value_counts().sort_values(ascending=True)

# %%
colors=["pink","yellow","skyblue","red","skyblue"]
plt.pie(h,labels=h.index,autopct="%1.1f",colors=colors,shadow=True)
plt.title("Graph for language in books")
plt.legend()
plt.show()

# %%
df.columns
# Out:
# Index(['index', 'Publishing Year', 'Book Name', 'Author', 'language_code',
#        'Author_Rating', 'Book_average_rating', 'Book_ratings_count', 'genre',
#        'gross sales', 'publisher revenue', 'sale price', 'sales rank',
#        'Publisher ', 'units sold'],
#       dtype='object')

# %%
df.groupby("Publisher ") ["publisher revenue"].sum().sort_values(ascending=False)
# Out:
# Publisher
# Penguin Group (USA) LLC                 191581.104
# Random House LLC                        174956.244
# Amazon Digital Services,  Inc.          141767.772
# HarperCollins Publishers                121769.814
# Hachette Book Group                     107410.968
# Simon and Schuster Digital Sales Inc     46858.206
# Macmillan                                31249.830
# HarperCollins Publishing                  2830.806
# HarperCollins Christian Publishing        2135.670
# Name: publisher revenue, dtype: float64

# %%
df.groupby("Author_Rating")["Book_average_rating"].mean().sort_values(ascending=False)
# Out:
# Author_Rating
# Famous          4.437708
# Excellent       4.164821
# Intermediate    3.911753
# Novice          3.370714
# Name: Book_average_rating, dtype: float64

# %%
df.groupby(["Book Name","genre"])["index"].sum().sort_values(ascending=True).head(10)
# Out:
# Book Name                                genre
# Beowulf                                  genre fiction    0
# Batman: Year One                         genre fiction    1
# Go Set a Watchman                        genre fiction    2
# When You Are Engulfed in Flames          fiction          3
# Daughter of Smoke & Bone                 genre fiction    4
# Red Queen                                genre fiction    5
# The Power of Habit                       genre fiction    6
# Midnight in the Garden of Good and Evil  nonfiction       7
# Hopeless                                 genre fiction    8
# A Little Princess                        genre fiction    9
# Name: index, dtype: int64

# %%
plt.scatter(df["Book_average_rating"],df["Book_ratings_count"])
plt.title("Book_average_rating VS Book_ratings_count")
plt.show()

# %%
p=df.groupby("Author")["gross sales"].sum().head(5).sort_values(ascending=True)
p
# Out:
# Author
# Adam Johnson                       108.90
# Adam Mansbach, Ricardo Cort̩s     113.85
# A.A. Milne, Ernest H. Shepard      214.92
# A.S.A. Harrison                    784.16
# Abbi Glines                       2990.16
# Name: gross sales, dtype: float64

# %%
p.sort_values(ascending=False).head(5).plot(kind="bar")
# Out:
# <Axes: xlabel='Author'>

# %%
df.groupby("Publishing Year")["units sold"].sum().plot(kind="line",marker="o")
plt.title("Total units sold per year")
plt.show()
